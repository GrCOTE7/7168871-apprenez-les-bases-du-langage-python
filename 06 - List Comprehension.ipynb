# %% [markdown]
# <a href="https://colab.research.google.com/github/GrCOTE7/7168871-apprenez-les-bases-du-langage-python/blob/main/06%20-%20List%20Comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6/30 - List Comprehension
# Les listes comprehension sont une facon habile de créer des listes sur une seule ligne de code, ce qui rend le code beaucoup plus rapide (car python est un langage assez lent)
#
# Les deux code ci-dessous effectuent chacun la meme opération. On peut voir (grace a la commande %%time) que le temps d'execution avec liste comprehenion est bien inférieur au temps d'execution avec la méthode append()

# %%
# %%time
liste = []
for i in range(1_000_000):
  liste.append(i**2)
# Out:
# CPU times: user 140 ms, sys: 21.1 ms, total: 161 ms
# Wall time: 169 ms

# %%
# %%time
liste = [i**2 for i in range(1_000_000)]
# Out:
# CPU times: user 93.4 ms, sys: 19 ms, total: 112 ms
# Wall time: 114 ms

# %%
list_base= [i for i in range(3)]
list_base
# Out:
# [0, 1, 2]

# %%
externe = int(1e4)
interne = int(1e4)

# %%
# %%time
liste_globale = [[i for i in range(interne)] for j in range(externe)]
len(liste_globale)
# Out:
# CPU times: user 6.24 s, sys: 2.15 s, total: 8.39 s
# Wall time: 8.75 s
# 10000

# %%
# %%time
liste_globale=[]
for j in range(externe):
  sous_liste=[]
  for i in range(interne):
    sous_liste.append(i)
  liste_globale.append(sous_liste)
len(liste_globale)
# Out:
# CPU times: user 11.7 s, sys: 1.64 s, total: 13.4 s
# Wall time: 13.7 s
# 10000

# %% [markdown]
# On peut rajouter des conditions **if** dans les listes comprehension, par exemple :

# %%
liste = [i**2 for i in range(100000) if (i % 2) == 0] # calcule i**2 seulement pour les nombres pairs.

print(liste[:10]) #affiche les 10 premiers éléments de la liste
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324]

# %% [markdown]
# ## Exercice et solution
#
# Le meme principe s'applique aux dictionnaires ! Essayez-donc de créer un dictionnaire qui contienne des clefs de 1 a 20, avec comme valeur le carré de chaque clef

# %%
# SOLUTION

dictionnaire = {k : k**2 for k in range(1, 21)}

print(dictionnaire)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256, 17: 289, 18: 324, 19: 361, 20: 400}
